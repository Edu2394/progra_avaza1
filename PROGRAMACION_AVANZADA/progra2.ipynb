# %%
class Coche():
    def __init__(self, marca, modelo, color, fecha):
        self.marca = marca
        self.modelo = modelo
        self.color = color
        self.fecha = fecha

    def descripcion(self):
        print(f"Este coche es de color {self.color} de la marca: {self.marca} y modelo {self.modelo} del año {self.fecha}")


lista = [
    Coche("Ford", "Mustang", "Azul", 2020),
    Coche("Chevrolet", "Camaro", "Rojo", 2019),
    Coche("BMW", "X5", "Negro", 2022),
    Coche("Audi", "A4", "Blanco", 2021),
    Coche("Toyota", "Corolla", "Gris", 2018),
    Coche("Honda", "Civic", "Azul", 2020),
    Coche("Nissan", "Sentra", "Plata", 2019),
    Coche("Mazda", "CX-5", "Rojo", 2021),
    Coche("Kia", "Sportage", "Negro", 2022),
    Coche("Hyundai", "Elantra", "Blanco", 2020),
    Coche("Volkswagen", "Jetta", "Gris", 2019),
    Coche("Mercedes-Benz", "C200", "Negro", 2021),
    Coche("BMW", "Serie 3", "Azul", 2020),
    Coche("Audi", "Q5", "Blanco", 2022),
    Coche("Ford", "Explorer", "Negro", 2021),
    Coche("Chevrolet", "Malibu", "Rojo", 2018),
    Coche("Toyota", "RAV4", "Verde", 2022),
    Coche("Honda", "CR-V", "Gris", 2021),
    Coche("Nissan", "X-Trail", "Blanco", 2020),
    Coche("Mazda", "3", "Azul", 2019),
    Coche("Kia", "Rio", "Rojo", 2018),
    Coche("Hyundai", "Tucson", "Negro", 2022),
    Coche("Volkswagen", "Passat", "Plata", 2020),
    Coche("Mercedes-Benz", "GLA", "Blanco", 2021),
    Coche("BMW", "X1", "Gris", 2019),
    Coche("Audi", "A6", "Negro", 2022),
    Coche("Ford", "Focus", "Azul", 2018),
    Coche("Chevrolet", "Spark", "Rojo", 2020),
    Coche("Toyota", "Yaris", "Blanco", 2019),
    Coche("Honda", "Fit", "Gris", 2018),
    Coche("Nissan", "Versa", "Plata", 2021),
    Coche("Mazda", "CX-30", "Negro", 2022),
    Coche("Kia", "Sorento", "Azul", 2021),
    Coche("Hyundai", "Santa Fe", "Blanco", 2020),
    Coche("Volkswagen", "Tiguan", "Gris", 2022),
    Coche("Mercedes-Benz", "E300", "Negro", 2019),
    Coche("BMW", "X3", "Blanco", 2021),
    Coche("Audi", "Q3", "Rojo", 2020),
    Coche("Ford", "Edge", "Gris", 2019),
    Coche("Chevrolet", "Tahoe", "Negro", 2022),
    Coche("Toyota", "Highlander", "Blanco", 2021),
    Coche("Honda", "Pilot", "Azul", 2020),
    Coche("Nissan", "Pathfinder", "Gris", 2019),
    Coche("Mazda", "6", "Rojo", 2018),
    Coche("Kia", "Soul", "Verde", 2021),
    Coche("Hyundai", "Accent", "Plata", 2019),
    Coche("Volkswagen", "Golf", "Azul", 2020),
    Coche("Mercedes-Benz", "A200", "Blanco", 2022)
]

for a in lista:
    a.descripcion()
# Out:
# Este coche es de color Azul de la marca: Ford y modelo Mustang del año 2020
# Este coche es de color Rojo de la marca: Chevrolet y modelo Camaro del año 2019
# Este coche es de color Negro de la marca: BMW y modelo X5 del año 2022
# Este coche es de color Blanco de la marca: Audi y modelo A4 del año 2021
# Este coche es de color Gris de la marca: Toyota y modelo Corolla del año 2018
# Este coche es de color Azul de la marca: Honda y modelo Civic del año 2020
# Este coche es de color Plata de la marca: Nissan y modelo Sentra del año 2019
# Este coche es de color Rojo de la marca: Mazda y modelo CX-5 del año 2021
# Este coche es de color Negro de la marca: Kia y modelo Sportage del año 2022
# Este coche es de color Blanco de la marca: Hyundai y modelo Elantra del año 2020
# Este coche es de color Gris de la marca: Volkswagen y modelo Jetta del año 2019
# Este coche es de color Negro de la marca: Mercedes-Benz y modelo C200 del año 2021
# ...

# %%
class App():
    def __init__(self,usuarios,capacidad,nombreusuario):
        self.usuarios=usuarios
        self.capacidad=capacidad
        self.nombreusuario=nombreusuario

    def login(self):
        if self.nombreusuario=="Dueño" and self.usuarios>=1:
            print(f"Bienvenido {self.nombreusuario}")
            print(f"TAu capacidad es de  {self.capacidad}")
    def incrementar(self,numero):
       self.capacidad+=numero
       return self.capacidad

usu1=App(35,356,"Dueño")
usu1.login()
usu1.incrementar(50)    
print(usu1.capacidad)
usu2=App(40,245,"Alan")
usu2.login()
# Out:
# Bienvenido Dueño
# TAu capacidad es de  356
# 406

# %%
class Alumno():
    def __init__(self,nombre,matricula):
        self.nombre=nombre
        self.matricula=matricula
        self.calif=[]
    def agregar_calificacion(self,calificacion):
        self.calif.append(calificacion)
    def calcular_promedio(self):
        return sum(self.calif)/len(self.calif)
    def estado_final(self):
        promedio=self.calcular_promedio()
        return "Aprobado" if promedio >=7 else "Reprobado"

# %%
class Grupo():
    def __init__(self,nombre_grupo):
        self.nombre_grupo=nombre_grupo
        self.alumnos=[]
    def agregar_alumno(self,alumno):
        self.alumnos.append(alumno)
    def mostrar_promedios(self):
        print(f"Promedios del grupo: {self.nombre_grupo}")
        for alumno in self.alumnos:
            promedio= alumno.calcular_promedio()
            estado=alumno.estadio_final()
            print(f"{alumno.nombre} ({alumno.matricula}): Promedio = {promedio:.2f}, Estado={estado}")
    def mejor_alumno(self):
        if not self.alumnos:
            print("No hay alumnos en el grupo")
            return None
        mejor= max(self.alumnos,key=lambda alumno: alumno.calcular_promedio())
        print(f"El mejor alumno es {mejor.nombre} ({mejor.matricula}) con un promedio de {mejor.calcular_promedio():.2f}")

# %%
alumno1=Alumno("Caro Sanchez",23345)
alumno2=Alumno("Eduardo Gomez",3557)
alumno3=Alumno("Beto",22222)

alumno1.agregar_calificacion(9.5)
alumno1.agregar_calificacion(9.5)
alumno1.agregar_calificacion(9)

alumno2.agregar_calificacion(9.5)
alumno2.agregar_calificacion(9.5)

alumno3.agregar_calificacion(6)
alumno3.agregar_calificacion(5)
alumno3.agregar_calificacion(7)
alumno3.agregar_calificacion(8)

alumno1.estado_final()#el return solamente te imrpime uno aunque pongas diferentes
print(f"La alumna {alumno1.nombre} tiene pormedio de: {alumno1.calcular_promedio():.2f} y esta: {alumno1.estado_final()}")
print(f"El alumno {alumno2.nombre} tiene pormedio de: {alumno2.calcular_promedio():.2f} y esta: {alumno2.estado_final()}")
print(f"El alumno {alumno3.nombre} tiene pormedio de: {alumno3.calcular_promedio():.2f} y esta: {alumno3.estado_final()}")
# Out:
# La alumna Caro Sanchez tiene pormedio de: 9.33 y esta: Aprobado
# El alumno Eduardo Gomez tiene pormedio de: 9.50 y esta: Aprobado
# El alumno Beto tiene pormedio de: 6.50 y esta: Reprobado

# %%
alumno3.estado_final()
# Out:
# 'Reprobado'

# %%
alumno2.estado_final()
# Out:
# 'Aprobado'
